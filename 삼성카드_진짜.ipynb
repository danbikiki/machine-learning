# %% [markdown]
# <a href="https://colab.research.google.com/github/danbikiki/machine-learning/blob/master/%EC%82%BC%EC%84%B1%EC%B9%B4%EB%93%9C_%EC%A7%84%EC%A7%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded=files.upload()
# Out:
#      <input type="file" id="files-04df05a6-9cb4-4d58-9580-07a3935d55b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04df05a6-9cb4-4d58-9580-07a3935d55b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving [Track2_데이터1] trend_w_demo.csv to [Track2_데이터1] trend_w_demo (1).csv

# %%
import pandas as pd
df1=pd.read_csv('[Track2_데이터1] trend_w_demo.csv',encoding='euc-kr')
df1
# Out:
#             YM Category  성별구분 연령대  ... 초등학생자녀스코어 중고생자녀스코어 대학생자녀스코어 전업주부스코어
# 0       202005      할인점     0   F  ...      high      mid      low     low
# 1       202005       취미     0   B  ...       mid      mid      low     low
# 2       202005  오픈마켓/소셜     1   D  ...       mid      mid      low     mid
# 3       202005       뷰티     0   D  ...       mid      mid      low     low
# 4       202005  오픈마켓/소셜     0   G  ...       mid      mid      mid     low
# ...        ...      ...   ...  ..  ...       ...      ...      ...     ...
# 452033  201904      전문몰     0   E  ...       low      low      low     low
# 452034  201904      할인점     0   H  ...       low      low      low     low
# 452035  201904      할인점     1   H  ...       low      low      low     low
# 452036  201904      할인점     0   H  ...       low      low      low     low
# 452037  201904      할인점     1   B  ...       mid      mid      low     mid
#
# [452038 rows x 10 columns]

# %%
df1_group=df1.groupby(['YM',"Category"]).count()
df1_group
# Out:
#                   성별구분    연령대  기혼스코어  ...  중고생자녀스코어  대학생자녀스코어  전업주부스코어
# YM     Category                       ...
# 201904 디저트       22918  22918  22918  ...     22918     22918    22918
#        면세점         947    947    947  ...       947       947      947
#        뷰티         5734   5734   5734  ...      5734      5734     5734
#        오픈마켓/소셜   18766  18766  18766  ...     18766     18766    18766
#        전문몰       30911  30911  30911  ...     30911     30911    30911
#        종합몰        4189   4189   4189  ...      4189      4189     4189
#        취미         5469   5469   5469  ...      5469      5469     5469
#        할인점       26721  26721  26721  ...     26721     26721    26721
#        항공/여행사     2132   2132   2132  ...      2132      2132     2132
#        호텔/숙박      2332   2332   2332  ...      2332      2332     2332
# 201905 디저트       23820  23820  23820  ...     23820     23820    23820
#        면세점         926    926    926  ...       926       926      926
# ...

# %%
df1_category=df1.groupby(['Category','YM']).count()
df1_category
# Out:
#                   성별구분    연령대  기혼스코어  ...  중고생자녀스코어  대학생자녀스코어  전업주부스코어
# Category YM                           ...
# 디저트      201904  22918  22918  22918  ...     22918     22918    22918
#          201905  23820  23820  23820  ...     23820     23820    23820
#          202004  20259  20259  20259  ...     20259     20259    20259
#          202005  22746  22746  22746  ...     22746     22746    22746
# 면세점      201904    947    947    947  ...       947       947      947
#          201905    926    926    926  ...       926       926      926
#          202004     56     56     56  ...        56        56       56
#          202005    139    139    139  ...       139       139      139
# 뷰티       201904   5734   5734   5734  ...      5734      5734     5734
#          201905   6130   6130   6130  ...      6130      6130     6130
#          202004   3978   3978   3978  ...      3978      3978     3978
#          202005   4611   4611   4611  ...      4611      4611     4611
# ...

# %%
df1_category.rename(columns={'성별구분':'num'},inplace=True)
df1_category.reset_index()
# Out:
#    Category      YM    num
# 0       디저트  201904  22918
# 1       디저트  201905  23820
# 2       디저트  202004  20259
# 3       디저트  202005  22746
# 4       면세점  201904    947
# 5       면세점  201905    926
# 6       면세점  202004     56
# 7       면세점  202005    139
# 8        뷰티  201904   5734
# 9        뷰티  201905   6130
# 10       뷰티  202004   3978
# 11       뷰티  202005   4611
# 12  오픈마켓/소셜  201904  18766
# 13  오픈마켓/소셜  201905  19343
# 14  오픈마켓/소셜  202004  20909
# 15  오픈마켓/소셜  202005  21724
# 16      전문몰  201904  30911
# 17      전문몰  201905  31655
# 18      전문몰  202004  31139
# 19      전문몰  202005  32357
# 20      종합몰  201904   4189
# 21      종합몰  201905   4175
# 22      종합몰  202004   4073
# 23      종합몰  202005   3682
# 24       취미  201904   5469
# 25       취미  201905   5507
# 26       취미  202004   3341
# 27       취미  202005   4132
# 28      할인점  201904  26721
# 29      할인점  201905  25216
# 30      할인점  202004  15756
# 31      할인점  202005  16943
# 32   항공/여행사  201904   2132
# ...

# %%
df1_category['num']
df1_category=pd.DataFrame(df1_category['num'])

# %%
sns.pointplot(x='YM',y='num',hue='Category',data=df1_category)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-230-1e186520b9ef> in <module>()
# ----> 1 sns.pointplot(x='YM',y='num',hue='Category',data=df1_category)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3331                             estimator, ci, n_boot, units, seed,
#    3332                             markers, linestyles, dodge, join, scale,
# -> 3333                             orient, color, palette, errwidth, capsize)
#    3334
#    3335     if ax is None:
#
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#이거 하고 리셋하고-두번째때 이거 실행 안하고 바로 아래껄로 넘어가면 돼!
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 3s (3,199 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import numpy as np
df1_log=np.log(df1_category['성별구분'])
df1_log=pd.DataFrame(df1_log)
df1_log.reset_index()
# Out:
#    Category      YM       성별구분
# 0       디저트  201904  10.039678
# 1       디저트  201905  10.078281
# 2       디저트  202004   9.916354
# 3       디저트  202005  10.032145
# 4       면세점  201904   6.853299
# 5       면세점  201905   6.830874
# 6       면세점  202004   4.025352
# 7       면세점  202005   4.934474
# 8        뷰티  201904   8.654169
# 9        뷰티  201905   8.720950
# 10       뷰티  202004   8.288534
# 11       뷰티  202005   8.436200
# 12  오픈마켓/소셜  201904   9.839802
# 13  오픈마켓/소셜  201905   9.870086
# 14  오픈마켓/소셜  202004   9.947935
# 15  오픈마켓/소셜  202005   9.986173
# 16      전문몰  201904  10.338867
# 17      전문몰  201905  10.362651
# 18      전문몰  202004  10.346216
# 19      전문몰  202005  10.384586
# 20      종합몰  201904   8.340217
# 21      종합몰  201905   8.336870
# 22      종합몰  202004   8.312135
# 23      종합몰  202005   8.211211
# 24       취미  201904   8.606851
# 25       취미  201905   8.613775
# 26       취미  202004   8.114025
# 27       취미  202005   8.326517
# 28      할인점  201904  10.193205
# ...

# %%
sns.pointplot(x='YM',y='성별구분',hue='Category',data=df1)
plt.rcParams['figure.figsize']=(15,15)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 
g=sns.FacetGrid(df1,col='Category',col_wrap=4)
g.map(sns.pointplot,'YM','성별구분')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:723: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df04=df1[df1['YM']==202004]
df04
# Out:
#             YM Category  성별구분 연령대  ... 초등학생자녀스코어 중고생자녀스코어 대학생자녀스코어 전업주부스코어
# 109094  202004  오픈마켓/소셜     1   D  ...       low      mid      low     low
# 109095  202004      디저트     1   B  ...      high      mid      mid     mid
# 109096  202004      전문몰     0   E  ...       low      low      low     low
# 109097  202004      전문몰     1   D  ...       mid      mid      low     mid
# 109098  202004  오픈마켓/소셜     1   E  ...       low      low      low     mid
# ...        ...      ...   ...  ..  ...       ...      ...      ...     ...
# 210463  202004  오픈마켓/소셜     1   D  ...       low      mid      low     mid
# 210464  202004      전문몰     1   D  ...       low      mid      low     low
# 210465  202004  오픈마켓/소셜     0   C  ...      high      low      low     low
# 210466  202004      할인점     0   F  ...       mid      mid      mid     low
# 210467  202004  오픈마켓/소셜     1   A  ...       mid      mid      mid     mid
#
# [101374 rows x 10 columns]

# %%
df04.groupby('연령대').count()
# Out:
#         YM  Category   성별구분  기혼스코어  ...  초등학생자녀스코어  중고생자녀스코어  대학생자녀스코어  전업주부스코어
# 연령대                                 ...
# A    16366     16366  16366  16366  ...      16366     16366     16366    16366
# B     7768      7768   7768   7768  ...       7768      7768      7768     7768
# C    12691     12691  12691  12691  ...      12691     12691     12691    12691
# D    16721     16721  16721  16721  ...      16721     16721     16721    16721
# E    11407     11407  11407  11407  ...      11407     11407     11407    11407
# F    16074     16074  16074  16074  ...      16074     16074     16074    16074
# G    11848     11848  11848  11848  ...      11848     11848     11848    11848
# H     8499      8499   8499   8499  ...       8499      8499      8499     8499
#
# [8 rows x 9 columns]
