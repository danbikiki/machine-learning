# %% [markdown]
# <a href="https://colab.research.google.com/github/danbikiki/machine-learning/blob/master/%EB%84%A4%EC%9D%B4%EB%B2%84_%EA%B8%88%EC%9C%B5_%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
code_df=pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13',header=0)[0]

# %%
code_df.종목코드=code_df.종목코드.map('{:06d}'.format)
code_df
# Out:
#             회사명    종목코드  ...                        홈페이지     지역
# 0           DSR  155660  ...          http://www.dsr.com  부산광역시
# 1            GS  078930  ...                         NaN  서울특별시
# 2         GS글로벌  001250  ...      http://www.gsgcorp.com  서울특별시
# 3     HDC현대산업개발  294870  ...      http://www.hdc-dvp.com  서울특별시
# 4         LG이노텍  011070  ...  http://www.lginnotek.co.kr  서울특별시
# ...         ...     ...  ...                         ...    ...
# 2361         툴젠  199800  ...      http://www.toolgen.com  서울특별시
# 2362   플럼라인생명과학  222670  ...       http://www.plsdna.com  서울특별시
# 2363    피엔에이치테크  239890  ...     http://www.phtech.co.kr    경기도
# 2364   한국미라클피플사  331660  ...       http://www.kmpc.co.kr    경기도
# 2365        휴벡셀  212310  ...          http://huvexel.com    경기도
#
# [2366 rows x 9 columns]

# %%
code_df1=code_df[['회사명','종목코드']]
code_df1
# Out:
#             회사명    종목코드
# 0           DSR  155660
# 1            GS  078930
# 2         GS글로벌  001250
# 3     HDC현대산업개발  294870
# 4         LG이노텍  011070
# ...         ...     ...
# 2361         툴젠  199800
# 2362   플럼라인생명과학  222670
# 2363    피엔에이치테크  239890
# 2364   한국미라클피플사  331660
# 2365        휴벡셀  212310
#
# [2366 rows x 2 columns]

# %%
code_df1.rename(columns={'회사명':'name','종목코드':'code'})
# Out:
#            name    code
# 0           DSR  155660
# 1            GS  078930
# 2         GS글로벌  001250
# 3     HDC현대산업개발  294870
# 4         LG이노텍  011070
# ...         ...     ...
# 2361         툴젠  199800
# 2362   플럼라인생명과학  222670
# 2363    피엔에이치테크  239890
# 2364   한국미라클피플사  331660
# 2365        휴벡셀  212310
#
# [2366 rows x 2 columns]

# %%
def get_url(item_name,code_df1):
  code=code_df1.query("name=='{}'".format(item_name))['code'].to_string(index=False)
  url="https://finance.naver.com/item/sise.nhn?code={}".format(code=code)
  print('요청 url={}'.format(url))
  return url

# %%
item_name='삼성전자'
url =get_url(item_name, code_df)
print(url)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# /usr/lib/python3.6/collections/__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# /usr/lib/python3.6/collections/__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
code_df=pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13',header=0)

# %%
code_df
# Out:
# [            회사명    종목코드  ...                        홈페이지     지역
#  0           DSR  155660  ...          http://www.dsr.com  부산광역시
#  1            GS   78930  ...                         NaN  서울특별시
#  2         GS글로벌    1250  ...      http://www.gsgcorp.com  서울특별시
#  3     HDC현대산업개발  294870  ...      http://www.hdc-dvp.com  서울특별시
#  4         LG이노텍   11070  ...  http://www.lginnotek.co.kr  서울특별시
#  ...         ...     ...  ...                         ...    ...
#  2361         툴젠  199800  ...      http://www.toolgen.com  서울특별시
#  2362   플럼라인생명과학  222670  ...       http://www.plsdna.com  서울특별시
#  2363    피엔에이치테크  239890  ...     http://www.phtech.co.kr    경기도
#  2364   한국미라클피플사  331660  ...       http://www.kmpc.co.kr    경기도
#  2365        휴벡셀  212310  ...          http://huvexel.com    경기도
#
#  [2366 rows x 9 columns]]

# %%
code_df[0]
# Out:
#             회사명    종목코드  ...                        홈페이지     지역
# 0           DSR  155660  ...          http://www.dsr.com  부산광역시
# 1            GS   78930  ...                         NaN  서울특별시
# 2         GS글로벌    1250  ...      http://www.gsgcorp.com  서울특별시
# 3     HDC현대산업개발  294870  ...      http://www.hdc-dvp.com  서울특별시
# 4         LG이노텍   11070  ...  http://www.lginnotek.co.kr  서울특별시
# ...         ...     ...  ...                         ...    ...
# 2361         툴젠  199800  ...      http://www.toolgen.com  서울특별시
# 2362   플럼라인생명과학  222670  ...       http://www.plsdna.com  서울특별시
# 2363    피엔에이치테크  239890  ...     http://www.phtech.co.kr    경기도
# 2364   한국미라클피플사  331660  ...       http://www.kmpc.co.kr    경기도
# 2365        휴벡셀  212310  ...          http://huvexel.com    경기도
#
# [2366 rows x 9 columns]

# %%
import pandas as pd
code_df=pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13',header=0)[0]

# %%
code_df.종목코드=code_df.종목코드.map('{:06d}'.format)

# %%
code_df
# Out:
#             회사명    종목코드  ...                        홈페이지     지역
# 0           DSR  155660  ...          http://www.dsr.com  부산광역시
# 1            GS  078930  ...                         NaN  서울특별시
# 2         GS글로벌  001250  ...      http://www.gsgcorp.com  서울특별시
# 3     HDC현대산업개발  294870  ...      http://www.hdc-dvp.com  서울특별시
# 4         LG이노텍  011070  ...  http://www.lginnotek.co.kr  서울특별시
# ...         ...     ...  ...                         ...    ...
# 2361         툴젠  199800  ...      http://www.toolgen.com  서울특별시
# 2362   플럼라인생명과학  222670  ...       http://www.plsdna.com  서울특별시
# 2363    피엔에이치테크  239890  ...     http://www.phtech.co.kr    경기도
# 2364   한국미라클피플사  331660  ...       http://www.kmpc.co.kr    경기도
# 2365        휴벡셀  212310  ...          http://huvexel.com    경기도
#
# [2366 rows x 9 columns]

# %%
code_df[['회사명','종목코드']]
# Out:
#             회사명    종목코드
# 0           DSR  155660
# 1            GS  078930
# 2         GS글로벌  001250
# 3     HDC현대산업개발  294870
# 4         LG이노텍  011070
# ...         ...     ...
# 2361         툴젠  199800
# 2362   플럼라인생명과학  222670
# 2363    피엔에이치테크  239890
# 2364   한국미라클피플사  331660
# 2365        휴벡셀  212310
#
# [2366 rows x 2 columns]

# %%
# Out:
# '011070'

# %%
code_df=code_df.rename(columns={'회사명':'name','종목코드':'code'})
code_df.head()
# Out:
#         name    code  ...                        홈페이지     지역
# 0        DSR  155660  ...          http://www.dsr.com  부산광역시
# 1         GS  078930  ...                         NaN  서울특별시
# 2      GS글로벌  001250  ...      http://www.gsgcorp.com  서울특별시
# 3  HDC현대산업개발  294870  ...      http://www.hdc-dvp.com  서울특별시
# 4      LG이노텍  011070  ...  http://www.lginnotek.co.kr  서울특별시
#
# [5 rows x 9 columns]

# %%
def get_url(item_name,code_df):
   code=code_df.query("name=='{}'".format(item_name))['code'].to_string(index=False).strip()
   url= 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
   print('요청 URL = {}'.format(url))
   return url

# %%
item_name='삼성전자'
url=get_url(item_name,code_df)

print(url)
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005930
# http://finance.naver.com/item/sise_day.nhn?code=005930

# %%
df = pd.DataFrame()
for page in range(1, 5):
    # 1~4까지 페이지를 읽어 데이터프레임에 저장한다.(append)
     pg_url='{url}&page={page}'.format(url=url, page=page)
     df=df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-69-2de0d727d45a> in <module>()
#       3     # 1~4까지 페이지를 읽어 데이터프레임에 저장한다.(append)
#       4      pg_url='{url}&page={page}'.format(url=url, page=page)
# ----> 5      df=df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     893
#     894         try:
# ...

# %%
df=pd.DataFrame()
for i in range(1,5):
  pg_url='{url}&amp;page={page}'.format(url=url,page=i)
  df=df.append(pd.read_html(pg_url,header=0)[0],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-63-541bbe8ba05c> in <module>()
#       2 for i in range(1,5):
#       3   pg_url='{url}&amp;page={page}'.format(url=url,page=i)
# ----> 4   df=df.append(pd.read_html(pg_url,header=0)[0],ignore_index=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     893
#     894         try:
# --> 895             tables = p.parse_tables()
# ...
